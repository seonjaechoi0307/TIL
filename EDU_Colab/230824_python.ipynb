# %% [markdown]
# ## 데이터 불러오기

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# ### 데이터 형태 확인

# %%
train_images.shape # 3차원 배열
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
test_images.shape # 3차원 배열
# Out:
# (10000, 28, 28)

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ## 신경망 구조

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation="relu"),  # 입력
    layers.Dense(10, activation="softmax") # 출력, 10이 의미하는 것은 예측할 범주의 개수
                                           # 수치 예측은 최종적으로 평균 수치 1개만 도출되기에 1만 있어도 됨
])

# %% [markdown]
# ## 컴파일 단계
# - 어떤 형태로 훈련을 시킬 것이냐를 정의
# - 경사하강법 : 기울기를 찾는데, step을 어떤 식으로 정의하는 것
# - 경사하강법의 종류도 되게 많음

# %%
model.compile(optimizer = "rmsprop",
              loss = "sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## 이미지 데이터 준비
# - 데이터를 모델에 맞는 크기로 변경
#  + 주의 이 때, 데이터타입 변경(연산할 때, 데이터 타입 미 매칭으로 인한 오류)
#  + 파이선 기본값 float64, 텐서플로 기본값 float32

# %%
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 7s 3ms/step - loss: 2.2347 - accuracy: 0.2591
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.6665 - accuracy: 0.6043
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.0418 - accuracy: 0.7479
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.7514 - accuracy: 0.8072
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.6101 - accuracy: 0.8361

# %%
test_digits = test_images[0:5]
predictions = model.predict(test_digits)
predictions[0].argmax()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 7

# %%
predictions[0][7]
# Out:
# 1.0

# %%
test_labels[0]
# Out:
# 7

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("테스트 정확도", test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 51.2795 - accuracy: 0.7285
# 테스트 정확도 0.7285000085830688
