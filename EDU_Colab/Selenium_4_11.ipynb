# %%
# Set up for running selenium in Google Colab
## You don't need to run this code if you do it in Jupyter notebook, or other local Python setting
# %%shell
sudo apt -y update
sudo apt install -y wget curl unzip
wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
dpkg -i libu2f-udev_1.1.4-1_all.deb
wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
dpkg -i google-chrome-stable_current_amd64.deb
CHROME_DRIVER_VERSION=`curl -sS chromedriver.storage.googleapis.com/LATEST_RELEASE`
wget -N https://chromedriver.storage.googleapis.com/$CHROME_DRIVER_VERSION/chromedriver_linux64.zip -P /tmp/
unzip -o /tmp/chromedriver_linux64.zip -d /tmp/
chmod +x /tmp/chromedriver
mv /tmp/chromedriver /usr/local/bin/chromedriver
pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [108 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [977 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [865 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [833 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,231 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,097 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,159 kB]
# Get:17 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,108 kB]
# Fetched 8,628 kB in 5s (1,762 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 19 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.13).
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# --2023-08-03 05:07:00--  http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.36, 91.189.91.82, 91.189.91.81, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3708 (3.6K) [application/x-debian-package]
# Saving to: ‘libu2f-udev_1.1.4-1_all.deb’
#
# libu2f-udev_1.1.4-1 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2023-08-03 05:07:01 (326 MB/s) - ‘libu2f-udev_1.1.4-1_all.deb’ saved [3708/3708]
#
# Selecting previously unselected package libu2f-udev.
# (Reading database ... 120500 files and directories currently installed.)
# Preparing to unpack libu2f-udev_1.1.4-1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1) ...
# Setting up libu2f-udev (1.1.4-1) ...
# --2023-08-03 05:07:02--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 142.250.128.93, 142.250.128.91, 142.250.128.190, ...
# Connecting to dl.google.com (dl.google.com)|142.250.128.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95154560 (91M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>]  90.75M  73.1MB/s    in 1.2s
#
# 2023-08-03 05:07:03 (73.1 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [95154560/95154560]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 120504 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (115.0.5790.170-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# --2023-08-03 05:07:15--  https://chromedriver.storage.googleapis.com/114.0.5735.90/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 64.233.183.128, 173.194.193.128, 173.194.194.128, ...
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|64.233.183.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7407250 (7.1M) [application/zip]
# Saving to: ‘/tmp/chromedriver_linux64.zip’
#
# chromedriver_linux6 100%[===================>]   7.06M  --.-KB/s    in 0.08s
#
# 2023-08-03 05:07:15 (89.9 MB/s) - ‘/tmp/chromedriver_linux64.zip’ saved [7407250/7407250]
#
# Archive:  /tmp/chromedriver_linux64.zip
#   inflating: /tmp/chromedriver
#   inflating: /tmp/LICENSE.chromedriver
# Collecting selenium
#   Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 39.6 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.2)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.2.0 selenium-4.11.2 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0

# %%
# !pip install chromedriver-autoinstaller
# Out:
# Collecting chromedriver-autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.2-py3-none-any.whl (7.4 kB)
# Installing collected packages: chromedriver-autoinstaller
# Successfully installed chromedriver-autoinstaller-0.6.2

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

import time
import pandas as pd
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import chromedriver_autoinstaller

print(selenium.__version__)
# Out:
# 4.11.2

# %%
# setup chrome options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # ensure GUI is off
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# set path to chromedriver as per your configuration
chromedriver_autoinstaller.install()

# set up the webdriver
driver = webdriver.Chrome(options=chrome_options)
print(driver)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e497ae356547c1c8ec2abc10c30db3e1")>

# %%
#해당 url로 이동
url = "https://www.naver.com/"
driver.get(url)

# 페이지 소스 가져오기 & title 태그 웹 사이트 제목 가져오기
html = driver.page_source
print(html.split("<title>")[1].split("</title>")[0])
# Out:
# NAVER

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "CafQpP18LUCMltsQtzEy"
client_secret = "ZD3O1LdXv6"
encText = urllib.parse.quote("맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 03 Aug 2023 14:18:51 +0900",
# 	"total":56794265,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"브라보였던 소노벨 제주 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/kjin4001\/223164763981",
# 			"description":"지난 주말 함덕해수욕장에서 지인들이랑 실컷 물놀이를 하고 나서 배가 고파 소노벨 제주 <b>맛집<\/b>에... 들어가자마자 엄청난 소노벨 제주 <b>맛집<\/b>의 오션뷰가 보여 일행들 모두 말을 잇지 못했거든요. 거기다가 내부... ",
# 			"bloggername":"그래그래마녀의 해피하우스",
# 			"bloggerlink":"blog.naver.com\/kjin4001",
# 			"postdate":"20230724"
# 		},
# 		{
# 			"title":"완벽했던 부천 장어 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lovejesus830\/223173434294",
# 			"description":"#부천장어<b>맛집<\/b> 오랜만에 대학교 선후배들과 만나서 전날 검색해두었던 부천 장어 <b>맛집<\/b>을 방문했어요. 10년 전통의 곳 답게 수준 높은 음식과 색다른 밑반찬들까지 즐길 수 있었어요. 이날 찾아간 식당은... ",
# 			"bloggername":"Fun Fun한 Life",
# 			"bloggerlink":"blog.naver.com\/lovejesus830",
# 			"postdate":"20230803"
# 		},
# 		{
# 			"title":"감탄했던 횡성 한우 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/whekrk\/223157122615",
# 			"description":"며칠 전 친구들이랑 같이 강원도로 여행을 떠났다가 유명한 횡성 한우 <b>맛집<\/b> 에 다녀왔어요. 직접 손질한... 저희는 횡성 한우 <b>맛집<\/b> 의 시그니쳐 메뉴들로 오더를 넣었답니다. 그러자 바로 숯불부터... ",
# 			"bloggername":"맛있는 수다, 언니네 작은 부엌",
# 			"bloggerlink":"blog.naver.com\/whekrk",
# 			"postdate":"20230715"
# 		},
# 		{
# 			"title":"급이 다른 서귀포 흑돼지 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/minsha321\/223166058114",
# 			"description":"며칠 전 친구들이랑 같이 제주로 여행을 떠났다가 입소문 자자한 서귀포 흑돼지 <b>맛집<\/b> 에 다녀왔어요.... 서귀포 흑돼지 <b>맛집<\/b> 의 영업시간은 오후5시20분부터 오후9시까지 라고 하니 이점 참고하세요. 내부로... ",
# 			"bloggername":"일해라 절해라",
# 			"bloggerlink":"blog.naver.com\/minsha321",
# 			"postdate":"20230726"
# 		},
# 		{
# 			"title":"또 가고싶던 영종도 회 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/mai28th\/223171963142",
# 			"description":"가족들과 인천으로 바람을 쐬러 갔던 지난 주말, 유명한 영종도 회 <b>맛집<\/b>에 들렀답니다. 고품격 활어회와... 수산물센터에서 오더를 한 뒤엔 영종도 회 <b>맛집<\/b>에서 운영하는 작약도로 향했어요. 말끔하게 정돈된... ",
# 			"bloggername":"블로그",
# 			"bloggerlink":"blog.naver.com\/mai28th",
# 			"postdate":"20230801"
# 		},
# 		{
# 			"title":"으뜸이었던 통영 현지인 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/hh0203hh\/223160889727",
# 			"description":"지난 주말에 친구들과 바람도 쐴겸 통영시립박물관에 갔다가 명성이 자자한 통영 현지인 <b>맛집<\/b>을... 여러가지 해산물 요리가 적혀있었는데 저희는 통영 현지인 <b>맛집<\/b>의 시그니처 메뉴인 5단 해물통찜을... ",
# 			"bloggername":"먹방스토리",
# 			"bloggerlink":"blog.naver.com\/hh0203hh",
# 			"postdate":"20230719"
# 		},
# 		{
# 			"title":"살수율 좋았던 광명 홍게 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/soultree23_\/223155260255",
# 			"description":"이번 주말에 친구에게 추천받았던 광명 홍게 <b>맛집<\/b>에 다녀왔어요. 테이크아웃 전문점인으로 매장이... 건물 지하에 주차가 가능했고, 주차권까지 제공해 주셔서 편하게 이용할 수 있었어요 광명 홍게 <b>맛집<\/b>은... ",
# 			"bloggername":"Y연세디앤유치과Y",
# 			"bloggerlink":"blog.naver.com\/soultree23_",
# 			"postdate":"20230713"
# 		},
# 		{
# 			"title":"급이 다른 강릉세인트존스호텔<b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/muse28\/223152259220",
# 			"description":"지인들과 함께 강릉으로 드라이브를 갔다가 미리 예약해둔 강릉세인트존스호텔<b>맛집<\/b> 을 방문했어요.... 저희는 강릉세인트존스호텔<b>맛집<\/b> 의 시그니쳐인 강문가세트로 주문을 넣었답니다. 5분 정도 지나자... ",
# 			"bloggername":"Colette Collect",
# 			"bloggerlink":"blog.naver.com\/muse28",
# 			"postdate":"20230710"
# 		},
# 		{
# 			"title":"완벽했던 영덕 대게 <b>맛집<\/b> [대명대게]",
# 			"link":"https:\/\/blog.naver.com\/boree808\/223164682654",
# 			"description":"얼마 전에 친구들과 함께 바람 쐬러 영덕에 갔다가 배가 고파 영덕 대게 <b>맛집<\/b>에 들렀어요. 항구 근처라... 다양한 요리의 구성이 좋은데다가 영덕 대게 <b>맛집<\/b>의 플레이팅도 화려해서 그런지 입이 떡하니 벌어졌죠.... ",
# 			"bloggername":"썩소와 강한 나로 무장한 보리",
# 			"bloggerlink":"blog.naver.com\/boree808",
# 			"postdate":"20230724"
# 		},
# 		{
# 			"title":"이유있던 제주공항 근처 <b>맛집<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lim265\/223149637376",
# 			"description":"며칠 전에 친구들이랑 같이 제주도로 여행을 갔다가 괜찮은 제주공항 근처 <b>맛집<\/b>에 다녀왔어요. 육질... 들어가는 길목에는 숙성고가 눈에 띄었는데 제주공항 근처 <b>맛집<\/b>에서는 최상의 돈육만을 사용한다고... ",
# 			"bloggername":"임정은",
# 			"bloggerlink":"blog.naver.com\/lim265",
# 			"postdate":"20230707"
# 		}
# 	]
# }
