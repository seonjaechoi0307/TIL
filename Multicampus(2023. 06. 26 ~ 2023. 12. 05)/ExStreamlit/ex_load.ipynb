# %%
import gdown
import pandas as pd

path = './서울특별시_전월세가_2022.csv'
df = pd.read_csv(path)
df.head(1)
# Out:
#    접수년도  자치구코드  자치구명  법정동코드   법정동명  지번구분코드 지번구분   본번   부번    층  ...  보증금(만원)  \
# 0  2022  11560  영등포구  12600  양평동2가     1.0   대지  1.0  3.0  6.0  ...    16000
#
#   임대료(만원)   건물명    건축년도  건물용도         계약기간  신규계약구분 갱신청구권사용 종전보증금 종전임대료
# 0       0  힘멜하임  2014.0  오피스텔  22.01~24.01      신규     NaN   0.0   NaN
#
# [1 rows x 23 columns]

# %%
import requests
from io import StringIO

# url = 'https://drive.google.com/file/d/1qT4HPBl3CEiwdk4sBmp3QynM0toM_UVx'
URL = "https://drive.google.com/file/d/1qT4HPBl3CEiwdk4sBmp3QynM0toM_UVx/view?usp=sharing"
path = "https://drive.google.com/uc?id=" + url.split('/')[-1]
print("▶ 공유파일 링크변환 경로명 : ", path)
df = pd.read_csv(path, encoding='utf-8')
df.head(1)
# Out:
# ▶ 공유파일 링크변환 경로명 :  https://drive.google.com/uc?id=1qT4HPBl3CEiwdk4sBmp3QynM0toM_UVx
#    접수년도  자치구코드  자치구명  법정동코드   법정동명  지번구분코드 지번구분   본번   부번    층  ...  보증금(만원)  \
# 0  2022  11560  영등포구  12600  양평동2가     1.0   대지  1.0  3.0  6.0  ...    16000
#
#   임대료(만원)   건물명    건축년도  건물용도         계약기간  신규계약구분 갱신청구권사용 종전보증금 종전임대료
# 0       0  힘멜하임  2014.0  오피스텔  22.01~24.01      신규     NaN   0.0   NaN
#
# [1 rows x 23 columns]
