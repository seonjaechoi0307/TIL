# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import notebook as nb
import numpy as np
import pandas as pd
import matplotlib
import statsmodels

# %%
# !ipython --version
print("notebook", nb.__version__)
print("numpy", np.__version__)
print("pandas", pd.__version__)
print("matplotlib", matplotlib.__version__)
print("statsmodels", statsmodels.__version__)
# Out:
# 7.34.0
# notebook 6.5.5
# numpy 1.23.5
# pandas 1.5.3
# matplotlib 3.7.1
# statsmodels 0.14.0

# %%
D_path = '/content/drive/MyDrive/Python-Statistical-Analysis/python_stat_sample-master/data'

# %%
# 챕터 1장 데이터
# 스포츠 시험 데이터를 불러온다.

# sport_df라는 함수에 아래의 경로로 ch1_sport_test.csv
# 라는 데이터 파일을 불러와서 데이터 프레임으로 저장하고
# index_column은 "학생번호"로 지정한다.
sport_df = pd.read_csv(D_path + '/ch1_sport_test.csv', index_col ='학생번호')
sport_df

# 변수 분류
# 번호: 명의 척도
# 학년: 간격 척도
# 악력: 비례 척도
# 윗몸: 비례 척도 + 이산형 변수
# 점수: 이산형이자 연속형 변수
# 순위: 순서 척도, 이산형 변수
# Out:
#       학년    악력  윗몸일으키기  점수  순위
# 학생번호
# 1      1  40.2      34  15   4
# 2      1  34.2      14   7  10
# 3      1  28.8      27  11   7
# 4      2  39.0      27  14   5
# 5      2  50.9      32  17   2
# 6      2  36.5      20   9   9
# 7      3  36.6      31  13   6
# 8      3  49.2      37  18   1
# 9      3  26.0      28  10   8
# 10     3  47.4      32  16   3

# %%
# sport_df라는 데이터 프레임의 "악력" 컬럼 추출하기
# 추출된 데이터는 시리즈(Series) 형태로 아래와 같이 출력된다.
# 데이터 프레임은 2차원 구조인 반면 시리즈는 1차원 구조이다.
sport_df['악력']
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %%
# 데이터가 주어지면 제일 먼저 확인해야하는 것은 데이터의 크기입니다.
# DataFrame의 크기는 shape라는 인스턴스 변수를 참조하면 알 수 있습니다.
sport_df.shape
# Out:
# (10, 5)
